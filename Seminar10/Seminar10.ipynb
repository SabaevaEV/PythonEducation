# %%
import pandas as pd

# %%
import seaborn as sys

# %% [markdown]
# Задача №63. Решение в группах
#
# Изобразите отношение households к population с помощью точечного графика
# Визуализировать longitude по отношения к median_house_value, используя линейный график
# Представить гистограмму по housing_median_age
# Изобразить гистограмму по median_house_value с оттенком housing_median_age

# %%
df = pd.read_csv('sample_data/california_housing_test.csv')

# %%
sys.scatterplot(data = df, x = 'households', y = 'population')
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %%
sys.relplot (x = 'longitude', y = 'median_house_value', kind = 'line', data = df)

# %%
sys.histplot(data = df, x = 'housing_median_age')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %%
sys.histplot(data = df, x = 'median_house_value', hue = 'housing_median_age')
# Out:
# <Axes: xlabel='median_house_value', ylabel='Count'>

# %% [markdown]
# Задача №65. Решение в группах
# Написать EDA для датасета про пингвинов
# Необходимо:
# ● Использовать 2-3 точечных графика
# ● Применить доп измерение в точечных графиках, используя
# аргументы hue, size, stile
# ● Использовать PairGrid с типом графика на ваш выбор
# ● Изобразить Heatmap
# ● Использовать 2-3 гистограммы

# %%
penguins = sys.load_dataset("penguins")

# %%
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
sys.scatterplot (data = penguins, x = 'sex', y = 'bill_length_mm')
# Out:
# <Axes: xlabel='sex', ylabel='bill_length_mm'>

# %%
sys.scatterplot (data = penguins, x = 'bill_depth_mm', y = 'bill_length_mm')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='bill_length_mm'>

# %%
sys.scatterplot (data = penguins, x = 'body_mass_g', y = 'island')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='island'>

# %%
sys.scatterplot (data = penguins, x = 'body_mass_g', y = 'bill_length_mm', hue = 'sex', size = 10)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='bill_length_mm'>

# %%
from seaborn.axisgrid import PairGrid
pen = ['bill_length_mm','bill_depth_mm','flipper_length_mm','body_mass_g']
p = sys.PairGrid(penguins[pen])
p.map(sys.scatterplot)

# %%
sys.histplot(data = penguins, x = 'bill_length_mm', hue = 'sex')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
sys.histplot(data = penguins, x = 'bill_length_mm', hue = 'body_mass_g')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
sys.histplot(data = penguins, x = 'island', hue = 'sex')
# Out:
# <Axes: xlabel='island', ylabel='Count'>

# %% [markdown]
# Задача №67. Решение в группах
# 1. Создать новый столбец в таблице с
# пингвинами, который будет отвечать за
# показатель длины клюва пингвина.
# high - длинный(от 42)
# middle - средний(от 35 до 42)
# low - маленький(до 35)

# %%
penguins.loc[penguins['bill_length_mm'] >= 42, 'bill_group'] = 'high'
penguins.loc[(penguins['bill_length_mm'] >= 35) & (penguins['bill_length_mm'] < 42), 'bill_group'] = 'middle'
penguins.loc[penguins['bill_length_mm'] < 35, 'bill_group'] = 'low'

# %%
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'bill_group'],
#       dtype='object')

# %% [markdown]
# Задача №69. Решение в группах
# 1. Изобразить гистограмму по flipper_length_mm
# с оттенком bill_group. Сделать анализ

# %%
penguins.groupby('bill_group')['bill_length_mm'].mean().plot(kind = 'bar')
# Out:
# <Axes: xlabel='bill_group'>

# %%
sys.displot(data = penguins, x = 'flipper_length_mm',hue = 'bill_group')
